# %% [markdown]
# # Q-Ctrl analysis of CCZ pulses with noise
# ## Noise in:
# ### - amplitude
# ### - detuning
# ### - phase
# ### - atom distance

# %%
# All A* terms handled by hermitian_part call later and not encoded here
# NN Hamiltonian
drive_operator = np.zeros((27, 27))
detuneDiag = np.zeros(27)
drive_operator[Hidx27['100'], Hidx27['r00']] = 1
detuneDiag[Hidx27['r00']] = 1
drive_operator[Hidx27['001'], Hidx27['00r']] = 1
detuneDiag[Hidx27['00r']] = 1
drive_operator[Hidx27['101'], Hidx27['r01']] = 1
drive_operator[Hidx27['101'], Hidx27['10r']] = 1
drive_operator[Hidx27['r01'], Hidx27['r0r']] = 1
detuneDiag[Hidx27['r01']] = 1
drive_operator[Hidx27['10r'], Hidx27['r0r']] = 1
detuneDiag[Hidx27['10r']] = 1
detuneDiag[Hidx27['r0r']] = 2
drive_operator[Hidx27['010'], Hidx27['0r0']] = 1
detuneDiag[Hidx27['0r0']] = 1
drive_operator[Hidx27['110'], Hidx27['r10']] = 1
drive_operator[Hidx27['110'], Hidx27['1r0']] = 1
drive_operator[Hidx27['1r0'], Hidx27['rr0']] = 1
detuneDiag[Hidx27['1r0']] = 1
drive_operator[Hidx27['r10'], Hidx27['rr0']] = 1
detuneDiag[Hidx27['r10']] = 1
detuneDiag[Hidx27['rr0']] = 2
drive_operator[Hidx27['011'], Hidx27['0r1']] = 1
drive_operator[Hidx27['011'], Hidx27['01r']] = 1
drive_operator[Hidx27['0r1'], Hidx27['0rr']] = 1
detuneDiag[Hidx27['0r1']] = 1
drive_operator[Hidx27['01r'], Hidx27['0rr']] = 1
detuneDiag[Hidx27['01r']] = 1
detuneDiag[Hidx27['0rr']] = 2
drive_operator[Hidx27['111'], Hidx27['r11']] = 1
drive_operator[Hidx27['111'], Hidx27['1r1']] = 1
drive_operator[Hidx27['111'], Hidx27['11r']] = 1
drive_operator[Hidx27['1r1'], Hidx27['rr1']] = 1
drive_operator[Hidx27['1r1'], Hidx27['1rr']] = 1
detuneDiag[Hidx27['1r1']] = 1
drive_operator[Hidx27['r11'], Hidx27['rr1']] = 1
drive_operator[Hidx27['r11'], Hidx27['r1r']] = 1
detuneDiag[Hidx27['r11']] = 1
drive_operator[Hidx27['11r'], Hidx27['r1r']] = 1
drive_operator[Hidx27['11r'], Hidx27['1rr']] = 1
detuneDiag[Hidx27['11r']] = 1
drive_operator[Hidx27['r1r'], Hidx27['rrr']] = 1
detuneDiag[Hidx27['r1r']] = 2
drive_operator[Hidx27['rr1'], Hidx27['rrr']] = 1
detuneDiag[Hidx27['rr1']] = 2
drive_operator[Hidx27['1rr'], Hidx27['rrr']] = 1
detuneDiag[Hidx27['1rr']] = 2
detuneDiag[Hidx27['rrr']] = 3

NN_detuning_operator = np.diag(detuneDiag)
NN_drive_operator=drive_operator
# Blockade interactions

Blockade = 50 * 2 * np.pi * 1e9 # 50 GHz * µm^6

# next nearest neighbor
blockN3 = np.zeros(27)
blockN3[[Hidx27['r0r'],Hidx27['r1r'],Hidx27['rrr']]] = Blockade
blockN3 = np.diag(blockN3)

# nearest neighbor
blockNN = np.zeros(27)
blockNN[[Hidx27['0rr'],Hidx27['1rr'],Hidx27['rr0'],Hidx27['rr1']]] = Blockade
blockNN[Hidx27['rrr']] = 2*Blockade
blockNN = np.diag(blockNN)
plt.imshow(blockNN)
plt.title("NN")
plt.show()
plt.imshow(blockN3)
plt.title("NNN")
plt.show()
plt.imshow(NN_drive_operator)
plt.title("NN Drive")
plt.show()
plt.imshow(NN_detuning_operator)
plt.title("NN Detune")
plt.show()

# NO NN terms
drive_operator = np.zeros((27, 27))
detuneDiag = np.zeros(27)
drive_operator[Hidx27['100'], Hidx27['r00']] = 1
detuneDiag[Hidx27['r00']] = 1
drive_operator[Hidx27['001'], Hidx27['00r']] = 1
detuneDiag[Hidx27['00r']] = 1
drive_operator[Hidx27['101'], Hidx27['r01']] = 1
drive_operator[Hidx27['101'], Hidx27['10r']] = 1
drive_operator[Hidx27['r01'], Hidx27['r0r']] = 1
detuneDiag[Hidx27['r01']] = 1
drive_operator[Hidx27['10r'], Hidx27['r0r']] = 1
detuneDiag[Hidx27['10r']] = 1
detuneDiag[Hidx27['r0r']] = 2
drive_operator[Hidx27['010'], Hidx27['0r0']] = 1
detuneDiag[Hidx27['0r0']] = 1
drive_operator[Hidx27['110'], Hidx27['r10']] = 1
drive_operator[Hidx27['110'], Hidx27['1r0']] = 1
detuneDiag[Hidx27['1r0']] = 1
detuneDiag[Hidx27['r10']] = 1
drive_operator[Hidx27['011'], Hidx27['0r1']] = 1
drive_operator[Hidx27['011'], Hidx27['01r']] = 1
detuneDiag[Hidx27['0r1']] = 1
detuneDiag[Hidx27['01r']] = 1
drive_operator[Hidx27['111'], Hidx27['r11']] = 1
drive_operator[Hidx27['111'], Hidx27['1r1']] = 1
drive_operator[Hidx27['111'], Hidx27['11r']] = 1
detuneDiag[Hidx27['1r1']] = 1
drive_operator[Hidx27['r11'], Hidx27['r1r']] = 1
detuneDiag[Hidx27['r11']] = 1
drive_operator[Hidx27['11r'], Hidx27['r1r']] = 1
detuneDiag[Hidx27['11r']] = 1
detuneDiag[Hidx27['r1r']] = 2
detuning_operator = np.diag(detuneDiag)

plt.imshow(drive_operator)
plt.title("Drive")
plt.show()
plt.imshow(detuning_operator)
plt.title("Detune")
plt.show()

# %%
def pulseGraph(pulse, rNoise=1, omegaNoise=1, deltaNoise=1, phiNoise=1, NN=False):
    graph = bo.Graph()
    omega = graph.pwc(
            values= pulse['output']['omega']['values'] * omegaNoise, 
            durations = pulse['output']['omega']['durations'], 
            name = 'omega')

    delta = graph.pwc(
        values=pulse['output']['delta']['values'] * deltaNoise,
        durations = pulse['output']['delta']['durations'], 
        name = 'delta')
    
    phi = graph.pwc(
        values=pulse['output']['phi']['values']* phiNoise,
        durations=pulse['output']['phi']['durations'],
        name = 'phi')

    # Real scalar signal representing the single qubit phase.
    psi = pulse['output']['psi']['value']

    # Define the Hamiltonian.
    if NN:
        r = pulse['output'].get('r',3)
        if type(r) != int:
            r = r['value']
        alpha = pulse['output'].get('alpha',6)
        if type(alpha) != int:
            alpha = alpha['value']
        r *= rNoise
        hamiltonian = (
            graph.hermitian_part(omega * graph.exp(1j * phi) * NN_drive_operator) + 
            delta * NN_detuning_operator + r**(-alpha)*(blockNN+blockN3/(2**alpha))
        )*pulse['output']['duration']['value']
    else:
        hamiltonian = (
        graph.hermitian_part(omega * graph.exp(1j * phi) * drive_operator) + 
        delta * detuning_operator )*pulse['output']['duration']['value']


    # Define the target operator.
    target = graph.target(
            operator = (cz_0 +
                graph.exp(1j * psi) * cz_1 + 
                graph.exp(1j * 2 * psi) * cz_11 + 
                graph.exp(1j * (3 * psi + np.pi)) * cz_111 ))

    # Unitary time evolution.
    unitary = (
        graph.time_evolution_operators_pwc(
            hamiltonian = hamiltonian, 
            sample_times = np.linspace(0, 1, 200)
, 
            name = 'unitary'
        )
    )

    # Infidelity.
    infidelity = (
        graph.infidelity_pwc(
            hamiltonian = hamiltonian,
            target = target,
            name = 'infidelity'
        )
    )

    # Cost function.
    cost_function = (
        graph.sum(
            infidelity
        )
    )
    cost_function.name = 'cost_function'
    
    return graph

def rerun(pulse, rNoise=1, omegaNoise=1, deltaNoise=1, phiNoise=1,NN=False):
    result = (
        bo.execute_graph(
            graph = pulseGraph(pulse, rNoise, omegaNoise, deltaNoise, phiNoise, NN),
            output_node_names = [ 
                'unitary',
                'infidelity'
            ]
        )
    )
    return result

# %%
# for i in range(len(pulse['output']['omega']['values'])):
#         omegaz.append(graph.pwc_signal(
#                 values= np.ndarray(pulse['output']['omega']['values'][i]), 
#                 duration = pulse['output']['omega']['durations'][i], 
#                 name = 'omega'+str(i)))
#     omega = graph.time_concatenate_pwc(omegaz, name="omega")
    
#     for i in range(len(pulse['output']['delta']['values'])):
#         deltaz.append(graph.pwc_signal(
#             values=np.ndarray(pulse['output']['delta']['values'][i]),
#             duration = pulse['output']['delta']['durations'][i], 
#             name = 'delta'+str(i)))
#     delta = graph.time_concatenate_pwc(deltaz, name="delta")
    
#     for i in range(len(pulse['output']['phi']['values'])):
#         phiz.append(graph.pwc_signal(
#             values=np.ndarray(pulse['output']['phi']['values'][i]),
#             duration=pulse['output']['phi']['durations'][i],
#             name = 'phi'+str(i)))
#     phi = graph.time_concatenate_pwc(phiz, name="phi")

# %%
HiFiPulseIDX = [0,69420]
HiFiPulseIDX_noNN = [0,69420]

for i in CCZz:
    if CCZz[i][0] < HiFiPulseIDX[1]:
        HiFiPulseIDX = [i, CCZz[i][0]]

for i in noNN:
    if noNN[i][0] < HiFiPulseIDX_noNN[1]:
        HiFiPulseIDX_noNN = [i, noNN[i][0]]

HiFiPulse = CCZz[HiFiPulseIDX[0]][1]
HiFiPulse_noNN = noNN[HiFiPulseIDX_noNN[0]][1]

# %%
pulse_pop(HiFiPulse,"State Population Probabilites - Finite Blockade + NNN")
pulse_pop(HiFiPulse_noNN,"State Population Probabilites - Infinite Blockade")

# %%
testrun = rerun(HiFiPulse,NN=True)
testrun['output']['infidelity']
# Out:
# Your task (action_id="2001443") has started.
# Your task (action_id="2001443") has completed.
# {'value': 1.3896466322105283e-07}

# %%
# a = np.linspace(-.05, -.01, 100)
# b = np.linspace(-.01, 0, 50)
# d = np.linspace(0, .01, 50)
# e = np.linspace(.01, .05, 100)
# d_offsets = np.concatenate((a,b,d,e))

# #d_offsets = np.linspace(-.05, .05, 201)
# offsetInfz = []
# for offset in d_offsets:
#     offsetInfz.append(rerun(HiFiPulse,1+offset,NN=True)['output']['infidelity']['value'])
# # Plotting Results
# plt.xlabel("% Offset from Ideal Atom Distance")
# plt.ylabel("Infidelity")
# plt.yscale("log")
# plt.plot(100 * d_offsets, offsetInfz, zorder=0)#, label='Simulated Data')
# plt.title(f"Infidelity as a Function of Atom Distance Offset \n\n Distance: {HiFiPulse['output']['r']['value']:.2} µm")

# plt.savefig('distanceRobustv3.png',dpi=300,bbox_inches='tight')

# %%
a = np.linspace(-.1, -.02, 100)
b = np.linspace(-.02, 0, 50)
d = np.linspace(0, .02, 50)
e = np.linspace(.02, .1, 100)
omega_offsets = np.concatenate((a,b,d,e))

omegaInfz = []
for offset in omega_offsets:
    omegaInfz.append(rerun(HiFiPulse,omegaNoise=1+offset,NN=True)['output']['infidelity']['value'])
# Out:
# Your task (action_id="2001444") has started.
# Your task (action_id="2001444") has completed.
# Your task (action_id="2001445") has started.
# Your task (action_id="2001445") has completed.
# Your task (action_id="2001446") has started.
# Your task (action_id="2001446") has completed.
# Your task (action_id="2001447") has started.
# Your task (action_id="2001447") has completed.
# Your task (action_id="2001448") has started.
# Your task (action_id="2001448") has completed.
# Your task (action_id="2001449") has started.
# Your task (action_id="2001449") has completed.
# Your task (action_id="2001450") has started.
# Your task (action_id="2001450") has completed.
# Your task (action_id="2001451") has started.
# Your task (action_id="2001451") has completed.
# Your task (action_id="2001452") has started.
# Your task (action_id="2001452") has completed.
# Your task (action_id="2001453") has started.
# Your task (action_id="2001453") has completed.
# Your task (action_id="2001454") has started.
# Your task (action_id="2001454") has completed.
# Your task (action_id="2001455") has started.
# Your task (action_id="2001455") has completed.
# Your task (action_id="2001456") has started.
# Your task (action_id="2001456") has completed.
# Your task (action_id="2001457") has started.
# Your task (action_id="2001457") has completed.
# Your task (action_id="2001458") has started.
# Your task (action_id="2001458") has completed.
# Your task (action_id="2001459") has started.
# Your task (action_id="2001459") has completed.
# Your task (action_id="2001460") has started.
# Your task (action_id="2001460") has completed.
# Your task (action_id="2001461") has started.
# Your task (action_id="2001461") has completed.
# Your task (action_id="2001462") has started.
# Your task (action_id="2001462") has completed.
# Your task (action_id="2001463") has started.
# Your task (action_id="2001463") has completed.
# Your task (action_id="2001464") has started.
# Your task (action_id="2001464") has completed.
# Your task (action_id="2001465") has started.
# Your task (action_id="2001465") has completed.
# Your task (action_id="2001466") has started.
# Your task (action_id="2001466") has completed.
# Your task (action_id="2001467") has started.
# Your task (action_id="2001467") has completed.
# Your task (action_id="2001468") has started.
# Your task (action_id="2001468") has completed.
# Your task (action_id="2001469") has started.
# Your task (action_id="2001469") has completed.
# Your task (action_id="2001470") has started.
# Your task (action_id="2001470") has completed.
# Your task (action_id="2001471") has started.
# Your task (action_id="2001471") has completed.
# Your task (action_id="2001472") has started.
# Your task (action_id="2001472") has completed.
# Your task (action_id="2001473") has started.
# Your task (action_id="2001473") has completed.
# Your task (action_id="2001474") has started.
# Your task (action_id="2001474") has completed.
# Your task (action_id="2001475") has started.
# Your task (action_id="2001475") has completed.
# Your task (action_id="2001476") has started.
# Your task (action_id="2001476") has completed.
# Your task (action_id="2001477") has started.
# Your task (action_id="2001477") has completed.
# Your task (action_id="2001478") has started.
# Your task (action_id="2001478") has completed.
# Your task (action_id="2001479") has started.
# Your task (action_id="2001479") has completed.
# Your task (action_id="2001480") has started.
# Your task (action_id="2001480") has completed.
# Your task (action_id="2001481") has started.
# Your task (action_id="2001481") has completed.
# Your task (action_id="2001482") has started.
# Your task (action_id="2001482") has completed.
# Your task (action_id="2001483") has started.
# Your task (action_id="2001483") has completed.
# Your task (action_id="2001484") has started.
# Your task (action_id="2001484") has completed.
# Your task (action_id="2001485") has started.
# Your task (action_id="2001485") has completed.
# Your task (action_id="2001486") has started.
# Your task (action_id="2001486") has completed.
# Your task (action_id="2001487") has started.
# Your task (action_id="2001487") has completed.
# Your task (action_id="2001488") has started.
# Your task (action_id="2001488") has completed.
# Your task (action_id="2001489") has started.
# Your task (action_id="2001489") has completed.
# Your task (action_id="2001490") has started.
# Your task (action_id="2001490") has completed.
# Your task (action_id="2001491") has started.
# Your task (action_id="2001491") has completed.
# Your task (action_id="2001492") has started.
# Your task (action_id="2001492") has completed.
# Your task (action_id="2001493") has started.
# Your task (action_id="2001493") has completed.
# Your task (action_id="2001494") has started.
# Your task (action_id="2001494") has completed.
# Your task (action_id="2001495") has started.
# Your task (action_id="2001495") has completed.
# Your task (action_id="2001496") has started.
# Your task (action_id="2001496") has completed.
# Your task (action_id="2001497") has started.
# Your task (action_id="2001497") has completed.
# Your task (action_id="2001498") has started.
# Your task (action_id="2001498") has completed.
# Your task (action_id="2001499") has started.
# Your task (action_id="2001499") has completed.
# Your task (action_id="2001500") has started.
# Your task (action_id="2001500") has completed.
# Your task (action_id="2001501") has started.
# Your task (action_id="2001501") has completed.
# Your task (action_id="2001502") has started.
# Your task (action_id="2001502") has completed.
# Your task (action_id="2001503") has started.
# Your task (action_id="2001503") has completed.
# Your task (action_id="2001504") has started.
# Your task (action_id="2001504") has completed.
# Your task (action_id="2001505") has started.
# Your task (action_id="2001505") has completed.
# Your task (action_id="2001506") has started.
# Your task (action_id="2001506") has completed.
# Your task (action_id="2001507") has started.
# Your task (action_id="2001507") has completed.
# Your task (action_id="2001508") has started.
# Your task (action_id="2001508") has completed.
# Your task (action_id="2001509") has started.
# Your task (action_id="2001509") has completed.
# Your task (action_id="2001510") has started.
# Your task (action_id="2001510") has completed.
# Your task (action_id="2001511") has started.
# Your task (action_id="2001511") has completed.
# Your task (action_id="2001512") has started.
# Your task (action_id="2001512") has completed.
# Your task (action_id="2001513") has started.
# Your task (action_id="2001513") has completed.
# Your task (action_id="2001514") has started.
# Your task (action_id="2001514") has completed.
# Your task (action_id="2001515") has started.
# Your task (action_id="2001515") has completed.
# Your task (action_id="2001516") has started.
# Your task (action_id="2001516") has completed.
# Your task (action_id="2001517") has started.
# Your task (action_id="2001517") has completed.
# Your task (action_id="2001518") has started.
# Your task (action_id="2001518") has completed.
# Your task (action_id="2001519") has started.
# Your task (action_id="2001519") has completed.
# Your task (action_id="2001520") has started.
# Your task (action_id="2001520") has completed.
# Your task (action_id="2001521") has started.
# Your task (action_id="2001521") has completed.
# Your task (action_id="2001522") has started.
# Your task (action_id="2001522") has completed.
# Your task (action_id="2001523") has started.
# Your task (action_id="2001523") has completed.
# Your task (action_id="2001524") has started.
# Your task (action_id="2001524") has completed.
# Your task (action_id="2001525") has started.
# Your task (action_id="2001525") has completed.
# Your task (action_id="2001526") has started.
# Your task (action_id="2001526") has completed.
# Your task (action_id="2001527") has started.
# Your task (action_id="2001527") has completed.
# Your task (action_id="2001528") has started.
# Your task (action_id="2001528") has completed.
# Your task (action_id="2001529") has started.
# Your task (action_id="2001529") has completed.
# Your task (action_id="2001530") has started.
# Your task (action_id="2001530") has completed.
# Your task (action_id="2001531") has started.
# Your task (action_id="2001531") has completed.
# Your task (action_id="2001532") has started.
# Your task (action_id="2001532") has completed.
# Your task (action_id="2001533") has started.
# Your task (action_id="2001533") has completed.
# Your task (action_id="2001534") has started.
# Your task (action_id="2001534") has completed.
# Your task (action_id="2001535") has started.
# Your task (action_id="2001535") has completed.
# Your task (action_id="2001536") has started.
# Your task (action_id="2001536") has completed.
# Your task (action_id="2001537") has started.
# Your task (action_id="2001537") has completed.
# Your task (action_id="2001538") has started.
# Your task (action_id="2001538") has completed.
# Your task (action_id="2001539") has started.
# Your task (action_id="2001539") has completed.
# Your task (action_id="2001540") has started.
# Your task (action_id="2001540") has completed.
# Your task (action_id="2001541") has started.
# Your task (action_id="2001541") has completed.
# Your task (action_id="2001542") has started.
# Your task (action_id="2001542") has completed.
# Your task (action_id="2001543") has started.
# Your task (action_id="2001543") has completed.
# Your task (action_id="2001544") has started.
# Your task (action_id="2001544") has completed.
# Your task (action_id="2001545") has started.
# Your task (action_id="2001545") has completed.
# Your task (action_id="2001546") has started.
# Your task (action_id="2001546") has completed.
# Your task (action_id="2001547") has started.
# Your task (action_id="2001547") has completed.
# Your task (action_id="2001548") has started.
# Your task (action_id="2001548") has completed.
# Your task (action_id="2001549") has started.
# Your task (action_id="2001549") has completed.
# Your task (action_id="2001550") has started.
# Your task (action_id="2001550") has completed.
# Your task (action_id="2001551") has started.
# Your task (action_id="2001551") has completed.
# Your task (action_id="2001552") has started.
# Your task (action_id="2001552") has completed.
# Your task (action_id="2001553") has started.
# Your task (action_id="2001553") has completed.
# Your task (action_id="2001554") has started.
# Your task (action_id="2001554") has completed.
# Your task (action_id="2001555") has started.
# Your task (action_id="2001555") has completed.
# Your task (action_id="2001556") has started.
# Your task (action_id="2001556") has completed.
# Your task (action_id="2001557") has started.
# Your task (action_id="2001557") has completed.
# Your task (action_id="2001558") has started.
# Your task (action_id="2001558") has completed.
# Your task (action_id="2001559") has started.
# Your task (action_id="2001559") has completed.
# Your task (action_id="2001560") has started.
# Your task (action_id="2001560") has completed.
# Your task (action_id="2001561") has started.
# Your task (action_id="2001561") has completed.
# Your task (action_id="2001562") has started.
# Your task (action_id="2001562") has completed.
# Your task (action_id="2001563") has started.
# Your task (action_id="2001563") has completed.
# Your task (action_id="2001564") has started.
# Your task (action_id="2001564") has completed.
# Your task (action_id="2001565") has started.
# Your task (action_id="2001565") has completed.
# Your task (action_id="2001566") has started.
# Your task (action_id="2001566") has completed.
# Your task (action_id="2001567") has started.
# Your task (action_id="2001567") has completed.
# Your task (action_id="2001568") has started.
# Your task (action_id="2001568") has completed.
# Your task (action_id="2001569") has started.
# Your task (action_id="2001569") has completed.
# Your task (action_id="2001570") has started.
# Your task (action_id="2001570") has completed.
# Your task (action_id="2001571") has started.
# Your task (action_id="2001571") has completed.
# Your task (action_id="2001572") has started.
# Your task (action_id="2001572") has completed.
# Your task (action_id="2001573") has started.
# Your task (action_id="2001573") has completed.
# Your task (action_id="2001574") has started.
# Your task (action_id="2001574") has completed.
# Your task (action_id="2001575") has started.
# Your task (action_id="2001575") has completed.
# Your task (action_id="2001576") has started.
# Your task (action_id="2001576") has completed.
# Your task (action_id="2001577") has started.
# Your task (action_id="2001577") has completed.
# Your task (action_id="2001578") has started.
# Your task (action_id="2001578") has completed.
# Your task (action_id="2001579") has started.
# Your task (action_id="2001579") has completed.
# Your task (action_id="2001580") has started.
# Your task (action_id="2001580") has completed.
# Your task (action_id="2001581") has started.
# Your task (action_id="2001581") has completed.
# Your task (action_id="2001582") has started.
# Your task (action_id="2001582") has completed.
# Your task (action_id="2001583") has started.
# Your task (action_id="2001583") has completed.
# Your task (action_id="2001584") has started.
# Your task (action_id="2001584") has completed.
# Your task (action_id="2001585") has started.
# Your task (action_id="2001585") has completed.
# Your task (action_id="2001586") has started.
# Your task (action_id="2001586") has completed.
# Your task (action_id="2001587") has started.
# Your task (action_id="2001587") has completed.
# Your task (action_id="2001588") has started.
# Your task (action_id="2001588") has completed.
# Your task (action_id="2001589") has started.
# Your task (action_id="2001589") has completed.
# Your task (action_id="2001590") has started.
# Your task (action_id="2001590") has completed.
# Your task (action_id="2001591") has started.
# Your task (action_id="2001591") has completed.
# Your task (action_id="2001592") has started.
# Your task (action_id="2001592") has completed.
# Your task (action_id="2001593") has started.
# Your task (action_id="2001593") has completed.
# Your task (action_id="2001594") has started.
# Your task (action_id="2001594") has completed.
# Your task (action_id="2001595") has started.
# Your task (action_id="2001595") has completed.
# Your task (action_id="2001596") has started.
# Your task (action_id="2001596") has completed.
# Your task (action_id="2001597") has started.
# Your task (action_id="2001597") has completed.
# Your task (action_id="2001598") has started.
# Your task (action_id="2001598") has completed.
# Your task (action_id="2001599") has started.
# Your task (action_id="2001599") has completed.
# Your task (action_id="2001600") has started.
# Your task (action_id="2001600") has completed.
# Your task (action_id="2001601") has started.
# Your task (action_id="2001601") has completed.
# Your task (action_id="2001602") has started.
# Your task (action_id="2001602") has completed.
# Your task (action_id="2001603") has started.
# Your task (action_id="2001603") has completed.
# Your task (action_id="2001604") has started.
# Your task (action_id="2001604") has completed.
# Your task (action_id="2001605") has started.
# Your task (action_id="2001605") has completed.
# Your task (action_id="2001606") has started.
# Your task (action_id="2001606") has completed.
# Your task (action_id="2001607") has started.
# Your task (action_id="2001607") has completed.
# Your task (action_id="2001608") has started.
# Your task (action_id="2001608") has completed.
# Your task (action_id="2001609") has started.
# Your task (action_id="2001609") has completed.
# Your task (action_id="2001610") has started.
# Your task (action_id="2001610") has completed.
# Your task (action_id="2001611") has started.
# Your task (action_id="2001611") has completed.
# Your task (action_id="2001612") has started.
# Your task (action_id="2001612") has completed.
# Your task (action_id="2001613") has started.
# Your task (action_id="2001613") has completed.
# Your task (action_id="2001614") has started.
# Your task (action_id="2001614") has completed.
# Your task (action_id="2001615") has started.
# Your task (action_id="2001615") has completed.
# Your task (action_id="2001616") has started.
# Your task (action_id="2001616") has completed.
# Your task (action_id="2001617") has started.
# Your task (action_id="2001617") has completed.
# Your task (action_id="2001618") has started.
# Your task (action_id="2001618") has completed.
# Your task (action_id="2001619") has started.
# Your task (action_id="2001619") has completed.
# Your task (action_id="2001620") has started.
# Your task (action_id="2001620") has completed.
# Your task (action_id="2001621") has started.
# Your task (action_id="2001621") has completed.
# Your task (action_id="2001622") has started.
# Your task (action_id="2001622") has completed.
# Your task (action_id="2001623") has started.
# Your task (action_id="2001623") has completed.
# Your task (action_id="2001624") has started.
# Your task (action_id="2001624") has completed.
# Your task (action_id="2001625") has started.
# Your task (action_id="2001625") has completed.
# Your task (action_id="2001626") has started.
# Your task (action_id="2001626") has completed.
# Your task (action_id="2001627") has started.
# Your task (action_id="2001627") has completed.
# Your task (action_id="2001628") has started.
# Your task (action_id="2001628") has completed.
# Your task (action_id="2001629") has started.
# Your task (action_id="2001629") has completed.
# Your task (action_id="2001630") has started.
# Your task (action_id="2001630") has completed.
# Your task (action_id="2001631") has started.
# Your task (action_id="2001631") has completed.
# Your task (action_id="2001632") has started.
# Your task (action_id="2001632") has completed.
# Your task (action_id="2001633") has started.
# Your task (action_id="2001633") has completed.
# Your task (action_id="2001634") has started.
# Your task (action_id="2001634") has completed.
# Your task (action_id="2001635") has started.
# Your task (action_id="2001635") has completed.
# Your task (action_id="2001636") has started.
# Your task (action_id="2001636") has completed.
# Your task (action_id="2001637") has started.
# Your task (action_id="2001637") has completed.
# Your task (action_id="2001638") has started.
# Your task (action_id="2001638") has completed.
# Your task (action_id="2001639") has started.
# Your task (action_id="2001639") has completed.
# Your task (action_id="2001640") has started.
# Your task (action_id="2001640") has completed.
# Your task (action_id="2001641") has started.
# Your task (action_id="2001641") has completed.
# Your task (action_id="2001642") has started.
# Your task (action_id="2001642") has completed.
# Your task (action_id="2001643") has started.
# Your task (action_id="2001643") has completed.
# Your task (action_id="2001644") has started.
# Your task (action_id="2001644") has completed.
# Your task (action_id="2001645") has started.
# Your task (action_id="2001645") has completed.
# Your task (action_id="2001646") has started.
# Your task (action_id="2001646") has completed.
# Your task (action_id="2001647") has started.
# Your task (action_id="2001647") has completed.
# Your task (action_id="2001648") has started.
# Your task (action_id="2001648") has completed.
# Your task (action_id="2001649") has started.
# Your task (action_id="2001649") has completed.
# Your task (action_id="2001650") has started.
# Your task (action_id="2001650") has completed.
# Your task (action_id="2001651") has started.
# Your task (action_id="2001651") has completed.
# Your task (action_id="2001652") is queued.
# Your task (action_id="2001652") has completed.
# Your task (action_id="2001653") has started.
# Your task (action_id="2001653") has completed.
# Your task (action_id="2001654") has started.
# Your task (action_id="2001654") has completed.
# Your task (action_id="2001655") has started.
# Your task (action_id="2001655") has completed.
# Your task (action_id="2001656") has started.
# Your task (action_id="2001656") has completed.
# Your task (action_id="2001657") has started.
# Your task (action_id="2001657") has completed.
# Your task (action_id="2001658") has started.
# Your task (action_id="2001658") has completed.
# Your task (action_id="2001659") has started.
# Your task (action_id="2001659") has completed.
# Your task (action_id="2001660") has started.
# Your task (action_id="2001660") has completed.
# Your task (action_id="2001661") has started.
# Your task (action_id="2001661") has completed.
# Your task (action_id="2001662") has started.
# Your task (action_id="2001662") has completed.
# Your task (action_id="2001663") has started.
# Your task (action_id="2001663") has completed.
# Your task (action_id="2001664") has started.
# Your task (action_id="2001664") has completed.
# Your task (action_id="2001665") has started.
# Your task (action_id="2001665") has completed.
# Your task (action_id="2001666") has started.
# Your task (action_id="2001666") has completed.
# Your task (action_id="2001667") has started.
# Your task (action_id="2001667") has completed.
# Your task (action_id="2001668") has started.
# Your task (action_id="2001668") has completed.
# Your task (action_id="2001669") has started.
# Your task (action_id="2001669") has completed.
# Your task (action_id="2001670") has started.
# Your task (action_id="2001670") has completed.
# Your task (action_id="2001671") has started.
# Your task (action_id="2001671") has completed.
# Your task (action_id="2001672") has started.
# Your task (action_id="2001672") has completed.
# Your task (action_id="2001673") has started.
# Your task (action_id="2001673") has completed.
# Your task (action_id="2001674") has started.
# Your task (action_id="2001674") has completed.
# Your task (action_id="2001675") has started.
# Your task (action_id="2001675") has completed.
# Your task (action_id="2001676") has started.
# Your task (action_id="2001676") has completed.
# Your task (action_id="2001677") has started.
# Your task (action_id="2001677") has completed.
# Your task (action_id="2001678") has started.
# Your task (action_id="2001678") has completed.
# Your task (action_id="2001679") has started.
# Your task (action_id="2001679") has completed.
# Your task (action_id="2001680") has started.
# Your task (action_id="2001680") has completed.
# Your task (action_id="2001681") has started.
# Your task (action_id="2001681") has completed.
# Your task (action_id="2001682") has started.
# Your task (action_id="2001682") has completed.
# Your task (action_id="2001683") has started.
# Your task (action_id="2001683") has completed.
# Your task (action_id="2001684") has started.
# Your task (action_id="2001684") has completed.
# Your task (action_id="2001685") is queued.
# Your task (action_id="2001685") has completed.
# Your task (action_id="2001686") has started.
# Your task (action_id="2001686") has completed.
# Your task (action_id="2001687") has started.
# Your task (action_id="2001687") has completed.
# Your task (action_id="2001688") has started.
# Your task (action_id="2001688") has completed.
# Your task (action_id="2001689") has started.
# Your task (action_id="2001689") has completed.
# Your task (action_id="2001690") is queued.
# Your task (action_id="2001690") has completed.
# Your task (action_id="2001691") has started.
# Your task (action_id="2001691") has completed.
# Your task (action_id="2001692") has started.
# Your task (action_id="2001692") has completed.
# Your task (action_id="2001693") has started.
# Your task (action_id="2001693") has completed.
# Your task (action_id="2001694") has started.
# Your task (action_id="2001694") has completed.
# Your task (action_id="2001695") has started.
# Your task (action_id="2001695") has completed.
# Your task (action_id="2001696") has started.
# Your task (action_id="2001696") has completed.
# Your task (action_id="2001697") has started.
# Your task (action_id="2001697") has completed.
# Your task (action_id="2001698") has started.
# Your task (action_id="2001698") has completed.
# Your task (action_id="2001699") has started.
# Your task (action_id="2001699") has completed.
# Your task (action_id="2001700") has started.
# Your task (action_id="2001700") has completed.
# Your task (action_id="2001701") has started.
# Your task (action_id="2001701") has completed.
# Your task (action_id="2001702") has started.
# Your task (action_id="2001702") has completed.
# Your task (action_id="2001703") has started.
# Your task (action_id="2001703") has completed.
# Your task (action_id="2001704") has started.
# Your task (action_id="2001704") has completed.
# Your task (action_id="2001705") has started.
# Your task (action_id="2001705") has completed.
# Your task (action_id="2001706") has started.
# Your task (action_id="2001706") has completed.
# Your task (action_id="2001707") has started.
# Your task (action_id="2001707") has completed.
# Your task (action_id="2001708") has started.
# Your task (action_id="2001708") has completed.
# Your task (action_id="2001709") has started.
# Your task (action_id="2001709") has completed.
# Your task (action_id="2001710") has started.
# Your task (action_id="2001710") has completed.
# Your task (action_id="2001711") has started.
# Your task (action_id="2001711") has completed.
# Your task (action_id="2001712") has started.
# Your task (action_id="2001712") has completed.
# Your task (action_id="2001713") has started.
# Your task (action_id="2001713") has completed.
# Your task (action_id="2001714") has started.
# Your task (action_id="2001714") has completed.
# Your task (action_id="2001715") has started.
# Your task (action_id="2001715") has completed.
# Your task (action_id="2001716") has started.
# Your task (action_id="2001716") has completed.
# Your task (action_id="2001717") has started.
# Your task (action_id="2001717") has completed.
# Your task (action_id="2001718") has started.
# Your task (action_id="2001718") has completed.
# Your task (action_id="2001719") has started.
# Your task (action_id="2001719") has completed.
# Your task (action_id="2001720") has started.
# Your task (action_id="2001720") has completed.
# Your task (action_id="2001721") has started.
# Your task (action_id="2001721") has completed.
# Your task (action_id="2001722") has started.
# Your task (action_id="2001722") has completed.
# Your task (action_id="2001723") has started.
# Your task (action_id="2001723") has completed.
# Your task (action_id="2001724") has started.
# Your task (action_id="2001724") has completed.
# Your task (action_id="2001725") has started.
# Your task (action_id="2001725") has completed.
# Your task (action_id="2001726") has started.
# Your task (action_id="2001726") has completed.
# Your task (action_id="2001727") has started.
# Your task (action_id="2001727") has completed.
# Your task (action_id="2001728") has started.
# Your task (action_id="2001728") has completed.
# Your task (action_id="2001729") has started.
# Your task (action_id="2001729") has completed.
# Your task (action_id="2001730") has started.
# Your task (action_id="2001730") has completed.
# Your task (action_id="2001731") has started.
# Your task (action_id="2001731") has completed.
# Your task (action_id="2001732") has started.
# Your task (action_id="2001732") has completed.
# Your task (action_id="2001733") has started.
# Your task (action_id="2001733") has completed.
# Your task (action_id="2001734") has started.
# Your task (action_id="2001734") has completed.
# Your task (action_id="2001735") has started.
# Your task (action_id="2001735") has completed.
# Your task (action_id="2001736") has started.
# Your task (action_id="2001736") has completed.
# Your task (action_id="2001737") has started.
# Your task (action_id="2001737") has completed.
# Your task (action_id="2001738") has started.
# Your task (action_id="2001738") has completed.
# Your task (action_id="2001739") has started.
# Your task (action_id="2001739") has completed.
# Your task (action_id="2001740") has started.
# Your task (action_id="2001740") has completed.
# Your task (action_id="2001741") has started.
# Your task (action_id="2001741") has completed.
# Your task (action_id="2001742") has started.
# Your task (action_id="2001742") has completed.
# Your task (action_id="2001743") has started.
# Your task (action_id="2001743") has completed.

# %%
a = np.linspace(-.1, -.02, 100)
b = np.linspace(-.02, 0, 50)
d = np.linspace(0, .02, 50)
e = np.linspace(.02, .1, 100)
delta_offsets = np.concatenate((a,b,d,e))

deltaInfz = []
for offset in delta_offsets:
    deltaInfz.append(rerun(HiFiPulse,deltaNoise=1+offset,NN=True)['output']['infidelity']['value'])
# Out:
# Your task (action_id="2001841") has started.
# Your task (action_id="2001841") has completed.
# Your task (action_id="2001842") has started.
# Your task (action_id="2001842") has completed.
# Your task (action_id="2001843") has started.
# Your task (action_id="2001843") has completed.
# Your task (action_id="2001844") has started.
# Your task (action_id="2001844") has completed.
# Your task (action_id="2001845") has started.
# Your task (action_id="2001845") has completed.
# Your task (action_id="2001846") has started.
# Your task (action_id="2001846") has completed.
# Your task (action_id="2001847") has started.
# Your task (action_id="2001847") has completed.
# Your task (action_id="2001848") has started.
# Your task (action_id="2001848") has completed.
# Your task (action_id="2001849") has started.
# Your task (action_id="2001849") has completed.
# Your task (action_id="2001850") has started.
# Your task (action_id="2001850") has completed.
# Your task (action_id="2001851") has started.
# Your task (action_id="2001851") has completed.
# Your task (action_id="2001852") has started.
# Your task (action_id="2001852") has completed.
# Your task (action_id="2001853") has started.
# Your task (action_id="2001853") has completed.
# Your task (action_id="2001854") has started.
# Your task (action_id="2001854") has completed.
# Your task (action_id="2001855") has started.
# Your task (action_id="2001855") has completed.
# Your task (action_id="2001856") has started.
# Your task (action_id="2001856") has completed.
# Your task (action_id="2001857") has started.
# Your task (action_id="2001857") has completed.
# Your task (action_id="2001858") has started.
# Your task (action_id="2001858") has completed.
# Your task (action_id="2001859") has started.
# Your task (action_id="2001859") has completed.
# Your task (action_id="2001860") has started.
# Your task (action_id="2001860") has completed.
# Your task (action_id="2001861") has started.
# Your task (action_id="2001861") has completed.
# Your task (action_id="2001862") has started.
# Your task (action_id="2001862") has completed.
# Your task (action_id="2001863") has started.
# Your task (action_id="2001863") has completed.
# Your task (action_id="2001864") has started.
# Your task (action_id="2001864") has completed.
# Your task (action_id="2001865") has started.
# Your task (action_id="2001865") has completed.
# Your task (action_id="2001866") has started.
# Your task (action_id="2001866") has completed.
# Your task (action_id="2001867") has started.
# Your task (action_id="2001867") has completed.
# Your task (action_id="2001868") has started.
# Your task (action_id="2001868") has completed.
# Your task (action_id="2001869") has started.
# Your task (action_id="2001869") has completed.
# Your task (action_id="2001870") has started.
# Your task (action_id="2001870") has completed.
# Your task (action_id="2001871") has started.
# Your task (action_id="2001871") has completed.
# Your task (action_id="2001872") has started.
# Your task (action_id="2001872") has completed.
# Your task (action_id="2001873") has started.
# Your task (action_id="2001873") has completed.
# Your task (action_id="2001874") has started.
# Your task (action_id="2001874") has completed.
# Your task (action_id="2001875") has started.
# Your task (action_id="2001875") has completed.
# Your task (action_id="2001876") has started.
# Your task (action_id="2001876") has completed.
# Your task (action_id="2001877") has started.
# Your task (action_id="2001877") has completed.
# Your task (action_id="2001878") has started.
# Your task (action_id="2001878") has completed.
# Your task (action_id="2001879") has started.
# Your task (action_id="2001879") has completed.
# Your task (action_id="2001880") has started.
# Your task (action_id="2001880") has completed.
# Your task (action_id="2001881") has started.
# Your task (action_id="2001881") has completed.
# Your task (action_id="2001882") has started.
# Your task (action_id="2001882") has completed.
# Your task (action_id="2001883") has started.
# Your task (action_id="2001883") has completed.
# Your task (action_id="2001884") has started.
# Your task (action_id="2001884") has completed.
# Your task (action_id="2001885") has started.
# Your task (action_id="2001885") has completed.
# Your task (action_id="2001886") has started.
# Your task (action_id="2001886") has completed.
# Your task (action_id="2001887") has started.
# Your task (action_id="2001887") has completed.
# Your task (action_id="2001888") has started.
# Your task (action_id="2001888") has completed.
# Your task (action_id="2001889") has started.
# Your task (action_id="2001889") has completed.
# Your task (action_id="2001890") has started.
# Your task (action_id="2001890") has completed.
# Your task (action_id="2001891") has started.
# Your task (action_id="2001891") has completed.
# Your task (action_id="2001892") has started.
# Your task (action_id="2001892") has completed.
# Your task (action_id="2001893") has started.
# Your task (action_id="2001893") has completed.
# Your task (action_id="2001894") has started.
# Your task (action_id="2001894") has completed.
# Your task (action_id="2001895") has started.
# Your task (action_id="2001895") has completed.
# Your task (action_id="2001896") has started.
# Your task (action_id="2001896") has completed.
# Your task (action_id="2001897") has started.
# Your task (action_id="2001897") has completed.
# Your task (action_id="2001898") has started.
# Your task (action_id="2001898") has completed.
# Your task (action_id="2001899") has started.
# Your task (action_id="2001899") has completed.
# Your task (action_id="2001900") has started.
# Your task (action_id="2001900") has completed.
# Your task (action_id="2001901") has started.
# Your task (action_id="2001901") has completed.
# Your task (action_id="2001902") has started.
# Your task (action_id="2001902") has completed.
# Your task (action_id="2001903") has started.
# Your task (action_id="2001903") has completed.
# Your task (action_id="2001904") has started.
# Your task (action_id="2001904") has completed.
# Your task (action_id="2001905") has started.
# Your task (action_id="2001905") has completed.
# Your task (action_id="2001906") has started.
# Your task (action_id="2001906") has completed.
# Your task (action_id="2001907") has started.
# Your task (action_id="2001907") has completed.
# Your task (action_id="2001908") has started.
# Your task (action_id="2001908") has completed.
# Your task (action_id="2001909") has started.
# Your task (action_id="2001909") has completed.
# Your task (action_id="2001910") has started.
# Your task (action_id="2001910") has completed.
# Your task (action_id="2001911") has started.
# Your task (action_id="2001911") has completed.
# Your task (action_id="2001912") has started.
# Your task (action_id="2001912") has completed.
# Your task (action_id="2001913") has started.
# Your task (action_id="2001913") has completed.
# Your task (action_id="2001914") has started.
# Your task (action_id="2001914") has completed.
# Your task (action_id="2001915") has started.
# Your task (action_id="2001915") has completed.
# Your task (action_id="2001916") has started.
# Your task (action_id="2001916") has completed.
# Your task (action_id="2001917") has started.
# Your task (action_id="2001917") has completed.
# Your task (action_id="2001918") has started.
# Your task (action_id="2001918") has completed.
# Your task (action_id="2001919") has started.
# Your task (action_id="2001919") has completed.
# Your task (action_id="2001920") has started.
# Your task (action_id="2001920") has completed.
# Your task (action_id="2001921") has started.
# Your task (action_id="2001921") has completed.
# Your task (action_id="2001922") has started.
# Your task (action_id="2001922") has completed.
# Your task (action_id="2001923") has started.
# Your task (action_id="2001923") has completed.
# Your task (action_id="2001924") has started.
# Your task (action_id="2001924") has completed.
# Your task (action_id="2001925") has started.
# Your task (action_id="2001925") has completed.
# Your task (action_id="2001926") has started.
# Your task (action_id="2001926") has completed.
# Your task (action_id="2001927") has started.
# Your task (action_id="2001927") has completed.
# Your task (action_id="2001928") has started.
# Your task (action_id="2001928") has completed.
# Your task (action_id="2001929") has started.
# Your task (action_id="2001929") has completed.
# Your task (action_id="2001930") has started.
# Your task (action_id="2001930") has completed.
# Your task (action_id="2001931") has started.
# Your task (action_id="2001931") has completed.
# Your task (action_id="2001932") has started.
# Your task (action_id="2001932") has completed.
# Your task (action_id="2001933") has started.
# Your task (action_id="2001933") has completed.
# Your task (action_id="2001934") has started.
# Your task (action_id="2001934") has completed.
# Your task (action_id="2001935") has started.
# Your task (action_id="2001935") has completed.
# Your task (action_id="2001936") has started.
# Your task (action_id="2001936") has completed.
# Your task (action_id="2001937") has started.
# Your task (action_id="2001937") has completed.
# Your task (action_id="2001938") has started.
# Your task (action_id="2001938") has completed.
# Your task (action_id="2001939") has started.
# Your task (action_id="2001939") has completed.
# Your task (action_id="2001940") has started.
# Your task (action_id="2001940") has completed.
# Your task (action_id="2001941") has started.
# Your task (action_id="2001941") has completed.
# Your task (action_id="2001942") has started.
# Your task (action_id="2001942") has completed.
# Your task (action_id="2001943") has started.
# Your task (action_id="2001943") has completed.
# Your task (action_id="2001944") has started.
# Your task (action_id="2001944") has completed.
# Your task (action_id="2001945") has started.
# Your task (action_id="2001945") has completed.
# Your task (action_id="2001946") has started.
# Your task (action_id="2001946") has completed.
# Your task (action_id="2001947") has started.
# Your task (action_id="2001947") has completed.
# Your task (action_id="2001948") has started.
# Your task (action_id="2001948") has completed.
# Your task (action_id="2001949") has started.
# Your task (action_id="2001949") has completed.
# Your task (action_id="2001950") has started.
# Your task (action_id="2001950") has completed.
# Your task (action_id="2001951") has started.
# Your task (action_id="2001951") has completed.
# Your task (action_id="2001952") has started.
# Your task (action_id="2001952") has completed.
# Your task (action_id="2001953") has started.
# Your task (action_id="2001953") has completed.
# Your task (action_id="2001954") has started.
# Your task (action_id="2001954") has completed.
# Your task (action_id="2001955") has started.
# Your task (action_id="2001955") has completed.
# Your task (action_id="2001956") has started.
# Your task (action_id="2001956") has completed.
# Your task (action_id="2001957") has started.
# Your task (action_id="2001957") has completed.
# Your task (action_id="2001958") has started.
# Your task (action_id="2001958") has completed.
# Your task (action_id="2001959") has started.
# Your task (action_id="2001959") has completed.
# Your task (action_id="2001960") has started.
# Your task (action_id="2001960") has completed.
# Your task (action_id="2001961") has started.
# Your task (action_id="2001961") has completed.
# Your task (action_id="2001962") has started.
# Your task (action_id="2001962") has completed.
# Your task (action_id="2001963") has started.
# Your task (action_id="2001963") has completed.
# Your task (action_id="2001964") has started.
# Your task (action_id="2001964") has completed.
# Your task (action_id="2001965") has started.
# Your task (action_id="2001965") has completed.
# Your task (action_id="2001966") has started.
# Your task (action_id="2001966") has completed.
# Your task (action_id="2001967") has started.
# Your task (action_id="2001967") has completed.
# Your task (action_id="2001968") has started.
# Your task (action_id="2001968") has completed.
# Your task (action_id="2001969") has started.
# Your task (action_id="2001969") has completed.
# Your task (action_id="2001970") has started.
# Your task (action_id="2001970") has completed.
# Your task (action_id="2001971") has started.
# Your task (action_id="2001971") has completed.
# Your task (action_id="2001972") has started.
# Your task (action_id="2001972") has completed.
# Your task (action_id="2001973") has started.
# Your task (action_id="2001973") has completed.
# Your task (action_id="2001974") has started.
# Your task (action_id="2001974") has completed.
# Your task (action_id="2001975") has started.
# Your task (action_id="2001975") has completed.
# Your task (action_id="2001976") has started.
# Your task (action_id="2001976") has completed.
# Your task (action_id="2001977") has started.
# Your task (action_id="2001977") has completed.
# Your task (action_id="2001978") has started.
# Your task (action_id="2001978") has completed.
# Your task (action_id="2001979") has started.
# Your task (action_id="2001979") has completed.
# Your task (action_id="2001980") has started.
# Your task (action_id="2001980") has completed.
# Your task (action_id="2001981") has started.
# Your task (action_id="2001981") has completed.
# Your task (action_id="2001982") has started.
# Your task (action_id="2001982") has completed.
# Your task (action_id="2001983") has started.
# Your task (action_id="2001983") has completed.
# Your task (action_id="2001984") has started.
# Your task (action_id="2001984") has completed.
# Your task (action_id="2001985") has started.
# Your task (action_id="2001985") has completed.
# Your task (action_id="2001986") has started.
# Your task (action_id="2001986") has completed.
# Your task (action_id="2001987") has started.
# Your task (action_id="2001987") has completed.
# Your task (action_id="2001988") has started.
# Your task (action_id="2001988") has completed.
# Your task (action_id="2001989") has started.
# Your task (action_id="2001989") has completed.
# Your task (action_id="2001990") has started.
# Your task (action_id="2001990") has completed.
# Your task (action_id="2001991") has started.
# Your task (action_id="2001991") has completed.
# Your task (action_id="2001992") has started.
# Your task (action_id="2001992") has completed.
# Your task (action_id="2001993") has started.
# Your task (action_id="2001993") has completed.
# Your task (action_id="2001994") has started.
# Your task (action_id="2001994") has completed.
# Your task (action_id="2001995") has started.
# Your task (action_id="2001995") has completed.
# Your task (action_id="2001996") has started.
# Your task (action_id="2001996") has completed.
# Your task (action_id="2001997") has started.
# Your task (action_id="2001997") has completed.
# Your task (action_id="2001998") has started.
# Your task (action_id="2001998") has completed.
# Your task (action_id="2001999") has started.
# Your task (action_id="2001999") has completed.
# Your task (action_id="2002000") has started.
# Your task (action_id="2002000") has completed.
# Your task (action_id="2002001") has started.
# Your task (action_id="2002001") has completed.
# Your task (action_id="2002002") has started.
# Your task (action_id="2002002") has completed.
# Your task (action_id="2002003") has started.
# Your task (action_id="2002003") has completed.
# Your task (action_id="2002004") has started.
# Your task (action_id="2002004") has completed.
# Your task (action_id="2002005") has started.
# Your task (action_id="2002005") has completed.
# Your task (action_id="2002006") has started.
# Your task (action_id="2002006") has completed.
# Your task (action_id="2002007") has started.
# Your task (action_id="2002007") has completed.
# Your task (action_id="2002008") has started.
# Your task (action_id="2002008") has completed.
# Your task (action_id="2002009") has started.
# Your task (action_id="2002009") has completed.
# Your task (action_id="2002010") has started.
# Your task (action_id="2002010") has completed.
# Your task (action_id="2002011") has started.
# Your task (action_id="2002011") has completed.
# Your task (action_id="2002012") has started.
# Your task (action_id="2002012") has completed.
# Your task (action_id="2002013") has started.
# Your task (action_id="2002013") has completed.
# Your task (action_id="2002014") has started.
# Your task (action_id="2002014") has completed.
# Your task (action_id="2002015") has started.
# Your task (action_id="2002015") has completed.
# Your task (action_id="2002016") has started.
# Your task (action_id="2002016") has completed.
# Your task (action_id="2002017") has started.
# Your task (action_id="2002017") has completed.
# Your task (action_id="2002018") has started.
# Your task (action_id="2002018") has completed.
# Your task (action_id="2002019") has started.
# Your task (action_id="2002019") has completed.
# Your task (action_id="2002020") has started.
# Your task (action_id="2002020") has completed.
# Your task (action_id="2002021") has started.
# Your task (action_id="2002021") has completed.
# Your task (action_id="2002022") has started.
# Your task (action_id="2002022") has completed.
# Your task (action_id="2002023") has started.
# Your task (action_id="2002023") has completed.
# Your task (action_id="2002024") has started.
# Your task (action_id="2002024") has completed.
# Your task (action_id="2002025") has started.
# Your task (action_id="2002025") has completed.
# Your task (action_id="2002026") has started.
# Your task (action_id="2002026") has completed.
# Your task (action_id="2002027") has started.
# Your task (action_id="2002027") has completed.
# Your task (action_id="2002028") has started.
# Your task (action_id="2002028") has completed.
# Your task (action_id="2002029") has started.
# Your task (action_id="2002029") has completed.
# Your task (action_id="2002030") has started.
# Your task (action_id="2002030") has completed.
# Your task (action_id="2002031") has started.
# Your task (action_id="2002031") has completed.
# Your task (action_id="2002032") has started.
# Your task (action_id="2002032") has completed.
# Your task (action_id="2002033") has started.
# Your task (action_id="2002033") has completed.
# Your task (action_id="2002034") has started.
# Your task (action_id="2002034") has completed.
# Your task (action_id="2002035") has started.
# Your task (action_id="2002035") has completed.
# Your task (action_id="2002036") has started.
# Your task (action_id="2002036") has completed.
# Your task (action_id="2002037") has started.
# Your task (action_id="2002037") has completed.
# Your task (action_id="2002038") has started.
# Your task (action_id="2002038") has completed.
# Your task (action_id="2002039") has started.
# Your task (action_id="2002039") has completed.
# Your task (action_id="2002040") has started.
# Your task (action_id="2002040") has completed.
# Your task (action_id="2002041") has started.
# Your task (action_id="2002041") has completed.
# Your task (action_id="2002042") has started.
# Your task (action_id="2002042") has completed.
# Your task (action_id="2002043") has started.
# Your task (action_id="2002043") has completed.
# Your task (action_id="2002044") has started.
# Your task (action_id="2002044") has completed.
# Your task (action_id="2002045") has started.
# Your task (action_id="2002045") has completed.
# Your task (action_id="2002046") has started.
# Your task (action_id="2002046") has completed.
# Your task (action_id="2002047") has started.
# Your task (action_id="2002047") has completed.
# Your task (action_id="2002048") has started.
# Your task (action_id="2002048") has completed.
# Your task (action_id="2002049") has started.
# Your task (action_id="2002049") has completed.
# Your task (action_id="2002050") has started.
# Your task (action_id="2002050") has completed.
# Your task (action_id="2002051") has started.
# Your task (action_id="2002051") has completed.
# Your task (action_id="2002052") has started.
# Your task (action_id="2002052") has completed.
# Your task (action_id="2002053") has started.
# Your task (action_id="2002053") has completed.
# Your task (action_id="2002054") has started.
# Your task (action_id="2002054") has completed.
# Your task (action_id="2002055") has started.
# Your task (action_id="2002055") has completed.
# Your task (action_id="2002056") has started.
# Your task (action_id="2002056") has completed.
# Your task (action_id="2002057") has started.
# Your task (action_id="2002057") has completed.
# Your task (action_id="2002058") has started.
# Your task (action_id="2002058") has completed.
# Your task (action_id="2002059") has started.
# Your task (action_id="2002059") has completed.
# Your task (action_id="2002060") has started.
# Your task (action_id="2002060") has completed.
# Your task (action_id="2002061") has started.
# Your task (action_id="2002061") has completed.
# Your task (action_id="2002062") has started.
# Your task (action_id="2002062") has completed.
# Your task (action_id="2002063") has started.
# Your task (action_id="2002063") has completed.
# Your task (action_id="2002064") has started.
# Your task (action_id="2002064") has completed.
# Your task (action_id="2002065") has started.
# Your task (action_id="2002065") has completed.
# Your task (action_id="2002066") has started.
# Your task (action_id="2002066") has completed.
# Your task (action_id="2002067") has started.
# Your task (action_id="2002067") has completed.
# Your task (action_id="2002068") has started.
# Your task (action_id="2002068") has completed.
# Your task (action_id="2002069") has started.
# Your task (action_id="2002069") has completed.
# Your task (action_id="2002070") has started.
# Your task (action_id="2002070") has completed.
# Your task (action_id="2002071") has started.
# Your task (action_id="2002071") has completed.
# Your task (action_id="2002072") has started.
# Your task (action_id="2002072") has completed.
# Your task (action_id="2002073") has started.
# Your task (action_id="2002073") has completed.
# Your task (action_id="2002074") has started.
# Your task (action_id="2002074") has completed.
# Your task (action_id="2002075") has started.
# Your task (action_id="2002075") has completed.
# Your task (action_id="2002076") has started.
# Your task (action_id="2002076") has completed.
# Your task (action_id="2002077") has started.
# Your task (action_id="2002077") has completed.
# Your task (action_id="2002078") has started.
# Your task (action_id="2002078") has completed.
# Your task (action_id="2002079") has started.
# Your task (action_id="2002079") has completed.
# Your task (action_id="2002080") has started.
# Your task (action_id="2002080") has completed.
# Your task (action_id="2002081") has started.
# Your task (action_id="2002081") has completed.
# Your task (action_id="2002082") has started.
# Your task (action_id="2002082") has completed.
# Your task (action_id="2002083") has started.
# Your task (action_id="2002083") has completed.
# Your task (action_id="2002084") has started.
# Your task (action_id="2002084") has completed.
# Your task (action_id="2002085") has started.
# Your task (action_id="2002085") has completed.
# Your task (action_id="2002086") has started.
# Your task (action_id="2002086") has completed.
# Your task (action_id="2002087") has started.
# Your task (action_id="2002087") has completed.
# Your task (action_id="2002088") has started.
# Your task (action_id="2002088") has completed.
# Your task (action_id="2002089") has started.
# Your task (action_id="2002089") has completed.
# Your task (action_id="2002090") has started.
# Your task (action_id="2002090") has completed.
# Your task (action_id="2002091") has started.
# Your task (action_id="2002091") has completed.
# Your task (action_id="2002092") has started.
# Your task (action_id="2002092") has completed.
# Your task (action_id="2002093") has started.
# Your task (action_id="2002093") has completed.
# Your task (action_id="2002094") has started.
# Your task (action_id="2002094") has completed.
# Your task (action_id="2002095") has started.
# Your task (action_id="2002095") has completed.
# Your task (action_id="2002096") has started.
# Your task (action_id="2002096") has completed.
# Your task (action_id="2002097") has started.
# Your task (action_id="2002097") has completed.
# Your task (action_id="2002098") has started.
# Your task (action_id="2002098") has completed.
# Your task (action_id="2002099") has started.
# Your task (action_id="2002099") has completed.
# Your task (action_id="2002100") has started.
# Your task (action_id="2002100") has completed.
# Your task (action_id="2002101") has started.
# Your task (action_id="2002101") has completed.
# Your task (action_id="2002102") has started.
# Your task (action_id="2002102") has completed.
# Your task (action_id="2002103") has started.
# Your task (action_id="2002103") has completed.
# Your task (action_id="2002104") has started.
# Your task (action_id="2002104") has completed.
# Your task (action_id="2002105") has started.
# Your task (action_id="2002105") has completed.
# Your task (action_id="2002106") has started.
# Your task (action_id="2002106") has completed.
# Your task (action_id="2002107") has started.
# Your task (action_id="2002107") has completed.
# Your task (action_id="2002108") has started.
# Your task (action_id="2002108") has completed.
# Your task (action_id="2002109") has started.
# Your task (action_id="2002109") has completed.
# Your task (action_id="2002110") has started.
# Your task (action_id="2002110") has completed.
# Your task (action_id="2002111") has started.
# Your task (action_id="2002111") has completed.
# Your task (action_id="2002112") has started.
# Your task (action_id="2002112") has completed.
# Your task (action_id="2002113") has started.
# Your task (action_id="2002113") has completed.
# Your task (action_id="2002114") has started.
# Your task (action_id="2002114") has completed.
# Your task (action_id="2002115") has started.
# Your task (action_id="2002115") has completed.
# Your task (action_id="2002116") has started.
# Your task (action_id="2002116") has completed.
# Your task (action_id="2002117") has started.
# Your task (action_id="2002117") has completed.
# Your task (action_id="2002118") has started.
# Your task (action_id="2002118") has completed.
# Your task (action_id="2002119") has started.
# Your task (action_id="2002119") has completed.
# Your task (action_id="2002120") has started.
# Your task (action_id="2002120") has completed.
# Your task (action_id="2002121") has started.
# Your task (action_id="2002121") has completed.
# Your task (action_id="2002122") has started.
# Your task (action_id="2002122") has completed.
# Your task (action_id="2002123") has started.
# Your task (action_id="2002123") has completed.
# Your task (action_id="2002124") has started.
# Your task (action_id="2002124") has completed.
# Your task (action_id="2002125") has started.
# Your task (action_id="2002125") has completed.
# Your task (action_id="2002126") has started.
# Your task (action_id="2002126") has completed.
# Your task (action_id="2002127") has started.
# Your task (action_id="2002127") has completed.
# Your task (action_id="2002128") has started.
# Your task (action_id="2002128") has completed.
# Your task (action_id="2002129") has started.
# Your task (action_id="2002129") has completed.
# Your task (action_id="2002130") has started.
# Your task (action_id="2002130") has completed.
# Your task (action_id="2002131") has started.
# Your task (action_id="2002131") has completed.
# Your task (action_id="2002132") has started.
# Your task (action_id="2002132") has completed.
# Your task (action_id="2002133") has started.
# Your task (action_id="2002133") has completed.
# Your task (action_id="2002134") has started.
# Your task (action_id="2002134") has completed.
# Your task (action_id="2002135") has started.
# Your task (action_id="2002135") has completed.
# Your task (action_id="2002136") has started.
# Your task (action_id="2002136") has completed.
# Your task (action_id="2002137") has started.
# Your task (action_id="2002137") has completed.
# Your task (action_id="2002138") has started.
# Your task (action_id="2002138") has completed.
# Your task (action_id="2002139") has started.
# Your task (action_id="2002139") has completed.
# Your task (action_id="2002140") has started.
# Your task (action_id="2002140") has completed.

# %%
a = np.linspace(-.1, -.02, 100)
b = np.linspace(-.02, 0, 50)
d = np.linspace(0, .02, 50)
e = np.linspace(.02, .1, 100)
phi_offsets = np.concatenate((a,b,d,e))

phiInfz = []
for offset in phi_offsets:
    phiInfz.append(rerun(HiFiPulse,phiNoise=1+offset,NN=True)['output']['infidelity']['value'])
# Out:
# Your task (action_id="2002141") has started.
# Your task (action_id="2002141") has completed.
# Your task (action_id="2002142") has started.
# Your task (action_id="2002142") has completed.
# Your task (action_id="2002143") has started.
# Your task (action_id="2002143") has completed.
# Your task (action_id="2002144") has started.
# Your task (action_id="2002144") has completed.
# Your task (action_id="2002145") has started.
# Your task (action_id="2002145") has completed.
# Your task (action_id="2002146") has started.
# Your task (action_id="2002146") has completed.
# Your task (action_id="2002147") has started.
# Your task (action_id="2002147") has completed.
# Your task (action_id="2002148") has started.
# Your task (action_id="2002148") has completed.
# Your task (action_id="2002149") has started.
# Your task (action_id="2002149") has completed.
# Your task (action_id="2002150") has started.
# Your task (action_id="2002150") has completed.
# Your task (action_id="2002151") has started.
# Your task (action_id="2002151") has completed.
# Your task (action_id="2002152") has started.
# Your task (action_id="2002152") has completed.
# Your task (action_id="2002153") has started.
# Your task (action_id="2002153") has completed.
# Your task (action_id="2002154") has started.
# Your task (action_id="2002154") has completed.
# Your task (action_id="2002155") has started.
# Your task (action_id="2002155") has completed.
# Your task (action_id="2002156") has started.
# Your task (action_id="2002156") has completed.
# Your task (action_id="2002157") has started.
# Your task (action_id="2002157") has completed.
# Your task (action_id="2002158") has started.
# Your task (action_id="2002158") has completed.
# Your task (action_id="2002159") has started.
# Your task (action_id="2002159") has completed.
# Your task (action_id="2002160") has started.
# Your task (action_id="2002160") has completed.
# Your task (action_id="2002161") has started.
# Your task (action_id="2002161") has completed.
# Your task (action_id="2002162") has started.
# Your task (action_id="2002162") has completed.
# Your task (action_id="2002163") has started.
# Your task (action_id="2002163") has completed.
# Your task (action_id="2002164") has started.
# Your task (action_id="2002164") has completed.
# Your task (action_id="2002165") has started.
# Your task (action_id="2002165") has completed.
# Your task (action_id="2002166") has started.
# Your task (action_id="2002166") has completed.
# Your task (action_id="2002167") has started.
# Your task (action_id="2002167") has completed.
# Your task (action_id="2002168") has started.
# Your task (action_id="2002168") has completed.
# Your task (action_id="2002169") has started.
# Your task (action_id="2002169") has completed.
# Your task (action_id="2002170") has started.
# Your task (action_id="2002170") has completed.
# Your task (action_id="2002171") has started.
# Your task (action_id="2002171") has completed.
# Your task (action_id="2002172") has started.
# Your task (action_id="2002172") has completed.
# Your task (action_id="2002173") has started.
# Your task (action_id="2002173") has completed.
# Your task (action_id="2002174") has started.
# Your task (action_id="2002174") has completed.
# Your task (action_id="2002175") has started.
# Your task (action_id="2002175") has completed.
# Your task (action_id="2002176") has started.
# Your task (action_id="2002176") has completed.
# Your task (action_id="2002177") has started.
# Your task (action_id="2002177") has completed.
# Your task (action_id="2002178") has started.
# Your task (action_id="2002178") has completed.
# Your task (action_id="2002179") has started.
# Your task (action_id="2002179") has completed.
# Your task (action_id="2002180") has started.
# Your task (action_id="2002180") has completed.
# Your task (action_id="2002181") has started.
# Your task (action_id="2002181") has completed.
# Your task (action_id="2002182") has started.
# Your task (action_id="2002182") has completed.
# Your task (action_id="2002183") has started.
# Your task (action_id="2002183") has completed.
# Your task (action_id="2002184") has started.
# Your task (action_id="2002184") has completed.
# Your task (action_id="2002185") has started.
# Your task (action_id="2002185") has completed.
# Your task (action_id="2002186") has started.
# Your task (action_id="2002186") has completed.
# Your task (action_id="2002187") has started.
# Your task (action_id="2002187") has completed.
# Your task (action_id="2002188") has started.
# Your task (action_id="2002188") has completed.
# Your task (action_id="2002189") has started.
# Your task (action_id="2002189") has completed.
# Your task (action_id="2002190") has started.
# Your task (action_id="2002190") has completed.
# Your task (action_id="2002191") has started.
# Your task (action_id="2002191") has completed.
# Your task (action_id="2002192") has started.
# Your task (action_id="2002192") has completed.
# Your task (action_id="2002193") has started.
# Your task (action_id="2002193") has completed.
# Your task (action_id="2002194") has started.
# Your task (action_id="2002194") has completed.
# Your task (action_id="2002195") has started.
# Your task (action_id="2002195") has completed.
# Your task (action_id="2002196") has started.
# Your task (action_id="2002196") has completed.
# Your task (action_id="2002197") has started.
# Your task (action_id="2002197") has completed.
# Your task (action_id="2002198") has started.
# Your task (action_id="2002198") has completed.
# Your task (action_id="2002199") has started.
# Your task (action_id="2002199") has completed.
# Your task (action_id="2002200") has started.
# Your task (action_id="2002200") has completed.
# Your task (action_id="2002201") has started.
# Your task (action_id="2002201") has completed.
# Your task (action_id="2002202") has started.
# Your task (action_id="2002202") has completed.
# Your task (action_id="2002203") has started.
# Your task (action_id="2002203") has completed.
# Your task (action_id="2002204") has started.
# Your task (action_id="2002204") has completed.
# Your task (action_id="2002205") has started.
# Your task (action_id="2002205") has completed.
# Your task (action_id="2002206") has started.
# Your task (action_id="2002206") has completed.
# Your task (action_id="2002207") has started.
# Your task (action_id="2002207") has completed.
# Your task (action_id="2002208") has started.
# Your task (action_id="2002208") has completed.
# Your task (action_id="2002209") has started.
# Your task (action_id="2002209") has completed.
# Your task (action_id="2002210") has started.
# Your task (action_id="2002210") has completed.
# Your task (action_id="2002211") has started.
# Your task (action_id="2002211") has completed.
# Your task (action_id="2002212") has started.
# Your task (action_id="2002212") has completed.
# Your task (action_id="2002213") has started.
# Your task (action_id="2002213") has completed.
# Your task (action_id="2002214") has started.
# Your task (action_id="2002214") has completed.
# Your task (action_id="2002215") has started.
# Your task (action_id="2002215") has completed.
# Your task (action_id="2002216") has started.
# Your task (action_id="2002216") has completed.
# Your task (action_id="2002217") has started.
# Your task (action_id="2002217") has completed.
# Your task (action_id="2002218") has started.
# Your task (action_id="2002218") has completed.
# Your task (action_id="2002219") has started.
# Your task (action_id="2002219") has completed.
# Your task (action_id="2002220") has started.
# Your task (action_id="2002220") has completed.
# Your task (action_id="2002221") has started.
# Your task (action_id="2002221") has completed.
# Your task (action_id="2002222") has started.
# Your task (action_id="2002222") has completed.
# Your task (action_id="2002223") has started.
# Your task (action_id="2002223") has completed.
# Your task (action_id="2002224") has started.
# Your task (action_id="2002224") has completed.
# Your task (action_id="2002225") has started.
# Your task (action_id="2002225") has completed.
# Your task (action_id="2002226") has started.
# Your task (action_id="2002226") has completed.
# Your task (action_id="2002227") has started.
# Your task (action_id="2002227") has completed.
# Your task (action_id="2002228") has started.
# Your task (action_id="2002228") has completed.
# Your task (action_id="2002229") has started.
# Your task (action_id="2002229") has completed.
# Your task (action_id="2002230") has started.
# Your task (action_id="2002230") has completed.
# Your task (action_id="2002231") has started.
# Your task (action_id="2002231") has completed.
# Your task (action_id="2002232") has started.
# Your task (action_id="2002232") has completed.
# Your task (action_id="2002233") has started.
# Your task (action_id="2002233") has completed.
# Your task (action_id="2002234") has started.
# Your task (action_id="2002234") has completed.
# Your task (action_id="2002235") has started.
# Your task (action_id="2002235") has completed.
# Your task (action_id="2002236") has started.
# Your task (action_id="2002236") has completed.
# Your task (action_id="2002237") has started.
# Your task (action_id="2002237") has completed.
# Your task (action_id="2002238") has started.
# Your task (action_id="2002238") has completed.
# Your task (action_id="2002239") has started.
# Your task (action_id="2002239") has completed.
# Your task (action_id="2002240") has started.
# Your task (action_id="2002240") has completed.
# Your task (action_id="2002241") has started.
# Your task (action_id="2002241") has completed.
# Your task (action_id="2002242") has started.
# Your task (action_id="2002242") has completed.
# Your task (action_id="2002243") has started.
# Your task (action_id="2002243") has completed.
# Your task (action_id="2002244") has started.
# Your task (action_id="2002244") has completed.
# Your task (action_id="2002245") has started.
# Your task (action_id="2002245") has completed.
# Your task (action_id="2002246") has started.
# Your task (action_id="2002246") has completed.
# Your task (action_id="2002247") has started.
# Your task (action_id="2002247") has completed.
# Your task (action_id="2002248") has started.
# Your task (action_id="2002248") has completed.
# Your task (action_id="2002249") has started.
# Your task (action_id="2002249") has completed.
# Your task (action_id="2002250") has started.
# Your task (action_id="2002250") has completed.
# Your task (action_id="2002251") has started.
# Your task (action_id="2002251") has completed.
# Your task (action_id="2002252") has started.
# Your task (action_id="2002252") has completed.
# Your task (action_id="2002253") has started.
# Your task (action_id="2002253") has completed.
# Your task (action_id="2002254") has started.
# Your task (action_id="2002254") has completed.
# Your task (action_id="2002255") has started.
# Your task (action_id="2002255") has completed.
# Your task (action_id="2002256") has started.
# Your task (action_id="2002256") has completed.
# Your task (action_id="2002257") has started.
# Your task (action_id="2002257") has completed.
# Your task (action_id="2002258") has started.
# Your task (action_id="2002258") has completed.
# Your task (action_id="2002259") has started.
# Your task (action_id="2002259") has completed.
# Your task (action_id="2002260") has started.
# Your task (action_id="2002260") has completed.
# Your task (action_id="2002261") has started.
# Your task (action_id="2002261") has completed.
# Your task (action_id="2002262") has started.
# Your task (action_id="2002262") has completed.
# Your task (action_id="2002263") has started.
# Your task (action_id="2002263") has completed.
# Your task (action_id="2002264") has started.
# Your task (action_id="2002264") has completed.
# Your task (action_id="2002265") has started.
# Your task (action_id="2002265") has completed.
# Your task (action_id="2002266") has started.
# Your task (action_id="2002266") has completed.
# Your task (action_id="2002267") has started.
# Your task (action_id="2002267") has completed.
# Your task (action_id="2002268") has started.
# Your task (action_id="2002268") has completed.
# Your task (action_id="2002269") has started.
# Your task (action_id="2002269") has completed.
# Your task (action_id="2002270") has started.
# Your task (action_id="2002270") has completed.
# Your task (action_id="2002271") has started.
# Your task (action_id="2002271") has completed.
# Your task (action_id="2002272") has started.
# Your task (action_id="2002272") has completed.
# Your task (action_id="2002273") has started.
# Your task (action_id="2002273") has completed.
# Your task (action_id="2002274") has started.
# Your task (action_id="2002274") has completed.
# Your task (action_id="2002275") has started.
# Your task (action_id="2002275") has completed.
# Your task (action_id="2002276") has started.
# Your task (action_id="2002276") has completed.
# Your task (action_id="2002277") has started.
# Your task (action_id="2002277") has completed.
# Your task (action_id="2002278") has started.
# Your task (action_id="2002278") has completed.
# Your task (action_id="2002279") has started.
# Your task (action_id="2002279") has completed.
# Your task (action_id="2002280") has started.
# Your task (action_id="2002280") has completed.
# Your task (action_id="2002281") has started.
# Your task (action_id="2002281") has completed.
# Your task (action_id="2002282") has started.
# Your task (action_id="2002282") has completed.
# Your task (action_id="2002283") has started.
# Your task (action_id="2002283") has completed.
# Your task (action_id="2002284") has started.
# Your task (action_id="2002284") has completed.
# Your task (action_id="2002285") has started.
# Your task (action_id="2002285") has completed.
# Your task (action_id="2002286") has started.
# Your task (action_id="2002286") has completed.
# Your task (action_id="2002287") has started.
# Your task (action_id="2002287") has completed.
# Your task (action_id="2002288") has started.
# Your task (action_id="2002288") has completed.
# Your task (action_id="2002289") has started.
# Your task (action_id="2002289") has completed.
# Your task (action_id="2002290") has started.
# Your task (action_id="2002290") has completed.
# Your task (action_id="2002291") has started.
# Your task (action_id="2002291") has completed.
# Your task (action_id="2002292") has started.
# Your task (action_id="2002292") has completed.
# Your task (action_id="2002293") has started.
# Your task (action_id="2002293") has completed.
# Your task (action_id="2002294") has started.
# Your task (action_id="2002294") has completed.
# Your task (action_id="2002295") has started.
# Your task (action_id="2002295") has completed.
# Your task (action_id="2002296") has started.
# Your task (action_id="2002296") has completed.
# Your task (action_id="2002297") has started.
# Your task (action_id="2002297") has completed.
# Your task (action_id="2002298") has started.
# Your task (action_id="2002298") has completed.
# Your task (action_id="2002299") has started.
# Your task (action_id="2002299") has completed.
# Your task (action_id="2002300") has started.
# Your task (action_id="2002300") has completed.
# Your task (action_id="2002301") has started.
# Your task (action_id="2002301") has completed.
# Your task (action_id="2002302") has started.
# Your task (action_id="2002302") has completed.
# Your task (action_id="2002303") has started.
# Your task (action_id="2002303") has completed.
# Your task (action_id="2002304") has started.
# Your task (action_id="2002304") has completed.
# Your task (action_id="2002305") has started.
# Your task (action_id="2002305") has completed.
# Your task (action_id="2002306") has started.
# Your task (action_id="2002306") has completed.
# Your task (action_id="2002307") has started.
# Your task (action_id="2002307") has completed.
# Your task (action_id="2002308") has started.
# Your task (action_id="2002308") has completed.
# Your task (action_id="2002309") has started.
# Your task (action_id="2002309") has completed.
# Your task (action_id="2002310") has started.
# Your task (action_id="2002310") has completed.
# Your task (action_id="2002311") has started.
# Your task (action_id="2002311") has completed.
# Your task (action_id="2002312") has started.
# Your task (action_id="2002312") has completed.
# Your task (action_id="2002313") has started.
# Your task (action_id="2002313") has completed.
# Your task (action_id="2002314") has started.
# Your task (action_id="2002314") has completed.
# Your task (action_id="2002315") has started.
# Your task (action_id="2002315") has completed.
# Your task (action_id="2002316") has started.
# Your task (action_id="2002316") has completed.
# Your task (action_id="2002317") has started.
# Your task (action_id="2002317") has completed.
# Your task (action_id="2002318") has started.
# Your task (action_id="2002318") has completed.
# Your task (action_id="2002319") has started.
# Your task (action_id="2002319") has completed.
# Your task (action_id="2002320") has started.
# Your task (action_id="2002320") has completed.
# Your task (action_id="2002321") has started.
# Your task (action_id="2002321") has completed.
# Your task (action_id="2002322") has started.
# Your task (action_id="2002322") has completed.
# Your task (action_id="2002323") has started.
# Your task (action_id="2002323") has completed.
# Your task (action_id="2002324") has started.
# Your task (action_id="2002324") has completed.
# Your task (action_id="2002325") has started.
# Your task (action_id="2002325") has completed.
# Your task (action_id="2002326") has started.
# Your task (action_id="2002326") has completed.
# Your task (action_id="2002327") has started.
# Your task (action_id="2002327") has completed.
# Your task (action_id="2002328") has started.
# Your task (action_id="2002328") has completed.
# Your task (action_id="2002329") has started.
# Your task (action_id="2002329") has completed.
# Your task (action_id="2002330") has started.
# Your task (action_id="2002330") has completed.
# Your task (action_id="2002331") has started.
# Your task (action_id="2002331") has completed.
# Your task (action_id="2002332") has started.
# Your task (action_id="2002332") has completed.
# Your task (action_id="2002333") has started.
# Your task (action_id="2002333") has completed.
# Your task (action_id="2002334") has started.
# Your task (action_id="2002334") has completed.
# Your task (action_id="2002335") has started.
# Your task (action_id="2002335") has completed.
# Your task (action_id="2002336") has started.
# Your task (action_id="2002336") has completed.
# Your task (action_id="2002337") has started.
# Your task (action_id="2002337") has completed.
# Your task (action_id="2002338") has started.
# Your task (action_id="2002338") has completed.
# Your task (action_id="2002339") has started.
# Your task (action_id="2002339") has completed.
# Your task (action_id="2002340") has started.
# Your task (action_id="2002340") has completed.
# Your task (action_id="2002341") has started.
# Your task (action_id="2002341") has completed.
# Your task (action_id="2002342") has started.
# Your task (action_id="2002342") has completed.
# Your task (action_id="2002343") has started.
# Your task (action_id="2002343") has completed.
# Your task (action_id="2002344") has started.
# Your task (action_id="2002344") has completed.
# Your task (action_id="2002345") has started.
# Your task (action_id="2002345") has completed.
# Your task (action_id="2002346") has started.
# Your task (action_id="2002346") has completed.
# Your task (action_id="2002347") has started.
# Your task (action_id="2002347") has completed.
# Your task (action_id="2002348") has started.
# Your task (action_id="2002348") has completed.
# Your task (action_id="2002349") has started.
# Your task (action_id="2002349") has completed.
# Your task (action_id="2002350") has started.
# Your task (action_id="2002350") has completed.
# Your task (action_id="2002351") has started.
# Your task (action_id="2002351") has completed.
# Your task (action_id="2002352") has started.
# Your task (action_id="2002352") has completed.
# Your task (action_id="2002353") has started.
# Your task (action_id="2002353") has completed.
# Your task (action_id="2002354") has started.
# Your task (action_id="2002354") has completed.
# Your task (action_id="2002355") has started.
# Your task (action_id="2002355") has completed.
# Your task (action_id="2002356") has started.
# Your task (action_id="2002356") has completed.
# Your task (action_id="2002357") has started.
# Your task (action_id="2002357") has completed.
# Your task (action_id="2002358") has started.
# Your task (action_id="2002358") has completed.
# Your task (action_id="2002359") has started.
# Your task (action_id="2002359") has completed.
# Your task (action_id="2002360") has started.
# Your task (action_id="2002360") has completed.
# Your task (action_id="2002361") has started.
# Your task (action_id="2002361") has completed.
# Your task (action_id="2002362") has started.
# Your task (action_id="2002362") has completed.
# Your task (action_id="2002363") has started.
# Your task (action_id="2002363") has completed.
# Your task (action_id="2002364") has started.
# Your task (action_id="2002364") has completed.
# Your task (action_id="2002365") has started.
# Your task (action_id="2002365") has completed.
# Your task (action_id="2002366") has started.
# Your task (action_id="2002366") has completed.
# Your task (action_id="2002367") has started.
# Your task (action_id="2002367") has completed.
# Your task (action_id="2002368") has started.
# Your task (action_id="2002368") has completed.
# Your task (action_id="2002369") has started.
# Your task (action_id="2002369") has completed.
# Your task (action_id="2002370") has started.
# Your task (action_id="2002370") has completed.
# Your task (action_id="2002371") has started.
# Your task (action_id="2002371") has completed.
# Your task (action_id="2002372") has started.
# Your task (action_id="2002372") has completed.
# Your task (action_id="2002373") has started.
# Your task (action_id="2002373") has completed.
# Your task (action_id="2002374") has started.
# Your task (action_id="2002374") has completed.
# Your task (action_id="2002375") has started.
# Your task (action_id="2002375") has completed.
# Your task (action_id="2002376") has started.
# Your task (action_id="2002376") has completed.
# Your task (action_id="2002377") has started.
# Your task (action_id="2002377") has completed.
# Your task (action_id="2002378") has started.
# Your task (action_id="2002378") has completed.
# Your task (action_id="2002379") has started.
# Your task (action_id="2002379") has completed.
# Your task (action_id="2002380") has started.
# Your task (action_id="2002380") has completed.
# Your task (action_id="2002381") has started.
# Your task (action_id="2002381") has completed.
# Your task (action_id="2002382") has started.
# Your task (action_id="2002382") has completed.
# Your task (action_id="2002383") has started.
# Your task (action_id="2002383") has completed.
# Your task (action_id="2002384") has started.
# Your task (action_id="2002384") has completed.
# Your task (action_id="2002385") has started.
# Your task (action_id="2002385") has completed.
# Your task (action_id="2002386") has started.
# Your task (action_id="2002386") has completed.
# Your task (action_id="2002387") has started.
# Your task (action_id="2002387") has completed.
# Your task (action_id="2002388") has started.
# Your task (action_id="2002388") has completed.
# Your task (action_id="2002389") has started.
# Your task (action_id="2002389") has completed.
# Your task (action_id="2002390") has started.
# Your task (action_id="2002390") has completed.
# Your task (action_id="2002391") has started.
# Your task (action_id="2002391") has completed.
# Your task (action_id="2002392") has started.
# Your task (action_id="2002392") has completed.
# Your task (action_id="2002393") has started.
# Your task (action_id="2002393") has completed.
# Your task (action_id="2002394") has started.
# Your task (action_id="2002394") has completed.
# Your task (action_id="2002395") has started.
# Your task (action_id="2002395") has completed.
# Your task (action_id="2002396") has started.
# Your task (action_id="2002396") has completed.
# Your task (action_id="2002397") has started.
# Your task (action_id="2002397") has completed.
# Your task (action_id="2002398") has started.
# Your task (action_id="2002398") has completed.
# Your task (action_id="2002399") has started.
# Your task (action_id="2002399") has completed.
# Your task (action_id="2002400") has started.
# Your task (action_id="2002400") has completed.
# Your task (action_id="2002401") has started.
# Your task (action_id="2002401") has completed.
# Your task (action_id="2002402") has started.
# Your task (action_id="2002402") has completed.
# Your task (action_id="2002403") has started.
# Your task (action_id="2002403") has completed.
# Your task (action_id="2002404") has started.
# Your task (action_id="2002404") has completed.
# Your task (action_id="2002405") has started.
# Your task (action_id="2002405") has completed.
# Your task (action_id="2002406") has started.
# Your task (action_id="2002406") has completed.
# Your task (action_id="2002407") has started.
# Your task (action_id="2002407") has completed.
# Your task (action_id="2002408") has started.
# Your task (action_id="2002408") has completed.
# Your task (action_id="2002409") has started.
# Your task (action_id="2002409") has completed.
# Your task (action_id="2002410") has started.
# Your task (action_id="2002410") has completed.
# Your task (action_id="2002411") has started.
# Your task (action_id="2002411") has completed.
# Your task (action_id="2002412") has started.
# Your task (action_id="2002412") has completed.
# Your task (action_id="2002413") has started.
# Your task (action_id="2002413") has completed.
# Your task (action_id="2002414") has started.
# Your task (action_id="2002414") has completed.
# Your task (action_id="2002415") has started.
# Your task (action_id="2002415") has completed.
# Your task (action_id="2002416") has started.
# Your task (action_id="2002416") has completed.
# Your task (action_id="2002417") has started.
# Your task (action_id="2002417") has completed.
# Your task (action_id="2002418") has started.
# Your task (action_id="2002418") has completed.
# Your task (action_id="2002419") has started.
# Your task (action_id="2002419") has completed.
# Your task (action_id="2002420") has started.
# Your task (action_id="2002420") has completed.
# Your task (action_id="2002421") has started.
# Your task (action_id="2002421") has completed.
# Your task (action_id="2002422") has started.
# Your task (action_id="2002422") has completed.
# Your task (action_id="2002423") has started.
# Your task (action_id="2002423") has completed.
# Your task (action_id="2002424") has started.
# Your task (action_id="2002424") has completed.
# Your task (action_id="2002425") has started.
# Your task (action_id="2002425") has completed.
# Your task (action_id="2002426") has started.
# Your task (action_id="2002426") has completed.
# Your task (action_id="2002427") has started.
# Your task (action_id="2002427") has completed.
# Your task (action_id="2002428") has started.
# Your task (action_id="2002428") has completed.
# Your task (action_id="2002429") has started.
# Your task (action_id="2002429") has completed.
# Your task (action_id="2002430") has started.
# Your task (action_id="2002430") has completed.
# Your task (action_id="2002431") has started.
# Your task (action_id="2002431") has completed.
# Your task (action_id="2002432") has started.
# Your task (action_id="2002432") has completed.
# Your task (action_id="2002433") has started.
# Your task (action_id="2002433") has completed.
# Your task (action_id="2002434") has started.
# Your task (action_id="2002434") has completed.
# Your task (action_id="2002435") has started.
# Your task (action_id="2002435") has completed.
# Your task (action_id="2002436") has started.
# Your task (action_id="2002436") has completed.
# Your task (action_id="2002437") has started.
# Your task (action_id="2002437") has completed.
# Your task (action_id="2002438") has started.
# Your task (action_id="2002438") has completed.
# Your task (action_id="2002439") has started.
# Your task (action_id="2002439") has completed.
# Your task (action_id="2002440") has started.
# Your task (action_id="2002440") has completed.

# %%
   # Plotting Results
plt.xlabel("% Offset from Ideal Amplitude")
plt.ylabel("Infidelity")
plt.yscale("log")
plt.plot(100 * omega_offsets, omegaInfz, zorder=0)#, label='Simulated Data')
plt.title("Infidelity as a Function of Amplitude Offset")

plt.savefig('omegaRobust2.png',dpi=300,bbox_inches='tight')

# %%
   # Plotting Results
plt.xlabel("% Offset from Ideal Detuning")
plt.ylabel("Infidelity")
plt.yscale("log")
plt.plot(100 * delta_offsets, deltaInfz, zorder=0)#, label='Simulated Data')
plt.title("Infidelity as a Function of Detuning Offset")

plt.savefig('deltaRobust2.png',dpi=300,bbox_inches='tight')

# %%
   # Plotting Results
plt.xlabel("% Offset from Ideal Phase")
plt.ylabel("Infidelity")
plt.yscale("log")
plt.plot(100 * phi_offsets, phiInfz, zorder=0)#, label='Simulated Data')
plt.title("/n/nInfidelity as a Function of Phase Offset")

plt.savefig('phiRobust2.png',dpi=300,bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt
import qctrlvisualizer as qv
import boulderopal as bo
import pickle

with open('Rabi50_noNN_resultz.pickle', 'rb') as handle:
    noNN = pickle.load(handle)

with open('Rabi50_resultz.pickle', 'rb') as handle:
    CCZz = pickle.load(handle)

plt.style.use(qv.get_qctrl_style())
controls_for_plots = lambda opt: {
    '$\\Delta$': opt['output']['delta'],
    '$\\Omega$': opt['output']['omega'],
    '$\\Phi$': opt['output']['phi']
}

# Dictionary for 27x27 Hamiltonian indexing

Hidx27 ={}
Hidx27['000'] = 0
Hidx27['100'] = 1
Hidx27['r00'] = 2
Hidx27['001'] = 3
Hidx27['00r'] = 4
Hidx27['101'] = 5
Hidx27['r01'] = 6
Hidx27['10r'] = 7
Hidx27['r0r'] = 8
Hidx27['010'] = 9
Hidx27['0r0'] = 10
Hidx27['110'] = 11
Hidx27['1r0'] = 12
Hidx27['r10'] = 13
Hidx27['rr0'] = 14
Hidx27['011'] = 15
Hidx27['0r1'] = 16
Hidx27['01r'] = 17
Hidx27['0rr'] = 18
Hidx27['111'] = 19
Hidx27['1r1'] = 20
Hidx27['r11'] = 21
Hidx27['11r'] = 22
Hidx27['r1r'] = 23
Hidx27['rr1'] = 24
Hidx27['1rr'] = 25
Hidx27['rrr'] = 26


# Components for the CCZ operator.
cz_0 = np.zeros(27)
cz_0[0] = 1
cz_0 = np.diag(cz_0)

cz_1 = np.zeros(27)
cz_1[[Hidx27['100'],Hidx27['010'],Hidx27['001']]] = 1
cz_1 = np.diag(cz_1)

cz_11 = np.zeros(27)
cz_11[[Hidx27['110'],Hidx27['101'],Hidx27['011']]] = 1
cz_11 = np.diag(cz_11)

cz_111 = np.zeros(27)
cz_111[Hidx27['111']] = 1
cz_111 = np.diag(cz_111)    

def pulse_pop(pulse,title):
    tau =  1 # * 1e-6 # s  *** use 1 when optimizing duration
    sample_times = np.linspace(0, tau, 200)

    u = pulse['output']['unitary']['value']
    psi0 = np.zeros(27)
    psi0[Hidx27['000']] = 1
    out0 = np.abs(np.transpose(psi0) @ u @ psi0)**2
    psi1 = np.zeros(27)
    psi1[Hidx27['100']] = 1
    out1 = np.abs(np.transpose(psi1) @ u @ psi1)**2
    psi11 = np.zeros(27)
    psi11[Hidx27['101']] = 1
    out11 = np.abs(np.transpose(psi11) @ u @ psi11)**2
    psi111 = np.zeros(27)
    psi111[Hidx27['111']] = 1
    out111 = np.abs(np.transpose(psi111) @ u @ psi111)**2
    plt.plot(1e9 * sample_times, out0)
    plt.plot(1e9 * sample_times, out1)
    plt.plot(1e9 * sample_times, out11)
    plt.plot(1e9 * sample_times, out111)
    plt.xlabel('Time (ns)')
    plt.ylabel('Population')
    plt.legend(['|0>','|1>','|11>','|111>'])
    plt.title(title)
    return plt.show()
# Out:
# Boulder Opal client update available.
# Latest version is 2.0.0, you have 1.3.2.
# Visit https://docs.q-ctrl.com/boulder-opal/changelog for the latest product updates.
